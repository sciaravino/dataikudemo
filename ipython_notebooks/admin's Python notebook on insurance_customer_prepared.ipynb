# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import dataiku
from dataiku import pandasutils as pdu
import pandas as pd

# %%
# Read the dataset as a Pandas dataframe in memory
# Note: here, we only read the first 100K rows. Other sampling options are available
dataset_insurance_customer_prepared = dataiku.Dataset("insurance_customer_prepared")
df = dataset_insurance_customer_prepared.get_dataframe(limit=100000)
df.head()
# Out:
#       id  age        job  marital    education bad_credit home auto     contact month day_of_week  duration  campaign  pdays  previous     poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed ad_response
# 0  10001   56  housemaid  married        basic         no   no   no  mobile app   may         mon       261         1      0         0  nonexistent           1.1          93.994          -36.4      4.857         5191          no
# 1  10002   57   services  married  high school        yes   no   no  mobile app   may         mon       149         1      0         0  nonexistent           1.1          93.994          -36.4      4.857         5191          no
# 2  10003   37   services  married  high school         no  yes   no  mobile app   may         mon       226         1      0         0  nonexistent           1.1          93.994          -36.4      4.857         5191          no
# 3  10004   40     admin.  married        basic         no   no   no  mobile app   may         mon       151         1      0         0  nonexistent           1.1          93.994          -36.4      4.857         5191          no
# 4  10005   56   services  married  high school         no   no  yes  mobile app   may         mon       307         1      0         0  nonexistent           1.1          93.994          -36.4      4.857         5191          no

# %%
# Get some simple descriptive statistics
pdu.audit(df)
# Out:
#        _a_variable _b_data_type  _c_cardinality  _d_missings             _e_sample_values
# 0               id        int64           41188            0               [10001, 10002]
# 1              age        int64              78            0                     [56, 57]
# 2              job       object              12            0        [housemaid, services]
# 3          marital       object               4            0            [married, single]
# 4        education       object               6            0         [basic, high school]
# 5       bad_credit       object               2            0                    [no, yes]
# 6             home       object               2            0                    [no, yes]
# 7             auto       object               2            0                    [no, yes]
# 8          contact       object               2            0        [mobile app, website]
# 9            month       object              10            0                   [may, jul]
# 10     day_of_week       object               5            0                   [mon, tue]
# 11        duration        int64            1544            0                   [261, 149]
# 12        campaign        int64              42            0                       [1, 2]
# 13           pdays        int64              26            0                       [0, 6]
# 14        previous        int64               8            0                       [0, 1]
# 15        poutcome       object               3            0       [nonexistent, failure]
# 16    emp.var.rate      float64              10            0                   [1.1, 1.4]
# 17  cons.price.idx      float64              26            0  [93.994, 93.91799999999999]
# 18   cons.conf.idx      float64              26            0               [-36.4, -42.7]
# 19       euribor3m      float64             316            0               [4.857, 4.856]
# 20     nr.employed        int64              11            0                 [5191, 5228]
# 21     ad_response       object               2            0                    [no, yes]
